# %% [markdown]
# # 연산자

# %% [markdown]
# ## 논리연산자

# %%
x = 6
y = 9

print((x > 5) and (y < 10))
print((x > 5) or (y < 10))
# Out:
# True
# True

# %%
x = 4
y = 9

print((x > 5) and (y < 10))
print((x > 5) or (y < 10))
# Out:
# False
# True

# %%
x = 10
print(x > 5)
print(not(x > 5)) # x > 5 아니다.
# Out:
# True
# False

# %% [markdown]
# ## 연습문제

# %% [markdown]
# ### Example 1-7. 값(반지름)을 입력 받아 원의 넓이를 구하는 프로그램 만들기

# %%
A = int(input("값을 입력하시요 : "))
3.14 * (A**2)
# 3.14 * (A * A)
# Out:
# 값을 입력하시요 : 5
# 78.5

# %% [markdown]
# ### Example 1-8. 값(x)을 입력 받아 아래의 함수 계산하기 (y 구하기)
# - 1) y = x² - x + 100

# %%
x = int(input("값을 입력하시요 : "))
(x**2) - x + 100
# (x * x) - x + 100
# Out:
# 값을 입력하시요 : 30
# 970

# %% [markdown]
# ### Example 1-9. 금액을 입력했을 때, 상품 가격에 따른 잔돈을 반환하는 자판기 프로그램 만들기(과제)

# %%
price = int(input('상품 가격은?'))
money = int(input('얼마를 넣으시겠습니까?'))

change = money - price
coin_500 = change // 500
change = change % 500

coin_100 = change // 100
change = change % 100

coin_50 = change // 50
change = change % 50

coin_10 = change // 10
change = change % 10
print(f'500원:{coin_500}개, 100원:{coin_100}개, 50원:{coin_50}개, 10원:{coin_10}개')
# Out:
# 상품 가격은?6700
# 얼마를 넣으시겠습니까?7350
# 500원:1개, 100원:1개, 50원:1개, 10원:0개
