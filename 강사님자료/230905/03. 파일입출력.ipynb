# %% [markdown]
# # 파일 입출력

# %% [markdown]
# ## print

# %%
print('최' '진' '영')
print('최'+'진'+'영')
print('최', '진', '영')
# Out:
# 최진영
# 최진영
# 최 진 영

# %%
for i in range(1,10):
  print(i , end = ' ')
# Out:
# 1 2 3 4 5 6 7 8 9

# %% [markdown]
# ## txt 파일 다루기

# %%
# 파일생성하기
f = open('text_file.txt', 'w') # mode = [r, w, a]
f.close()

# %%
# 파일 생성 후 값 작성하기
f = open('text_file2.txt', 'w')
for i in range(1, 11):
  f.write(f'{i}번째 줄입니다.\n')
f.close()

# %%
# 파일 열어서 값 추가하기
f = open('text_file2.txt', 'a')
for i in range(11, 20):
  f.write(f'{i}번째 줄입니다.\n')
f.close()

# %%
# 파일 읽기(readline) : 한줄 출력
f = open('text_file2.txt', 'r')
line = f.readline()
print(line)
f.close()
# Out:
# 1번째 줄입니다.

# %%
# 파일 읽기(readline) : 한줄 출력 + 반복문 활용
f = open('text_file2.txt', 'r')
while True:
  line = f.readline()
  if not line:
    break
  print(line, end = '')
f.close()

# %%
# 파일 읽기(readlines)
f = open('text_file2.txt', 'r')
lines = f.readlines()
for line in lines:
    print(line)
f.close()

# %%
f = open('text_file2.txt', 'r')
data = f.read()
print(data)
f.close()

# %%
# f = open("foo.txt", 'w')
# f.write("Life is too short, you need python")
# f.close()

with open("foo.txt", "w") as f:
    f.write("Life is too short, you need python")
